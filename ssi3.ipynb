# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("example_data.csv")
data
# Out:
#        Status  Age                                          Education     Sex
# 0    Approved   45             Associate degree (for example: AA, AS)    Male  \
# 1    Approved   48        Bachelor's degree (for example: BA, AB, BS)    Male
# 2    Approved   30             Associate degree (for example: AA, AS)  Female
# 3    Approved   27        Bachelor's degree (for example: BA, AB, BS)  Female
# 4    Approved   27  High school graduate - high school diploma or ...  Female
# ..        ...  ...                                                ...     ...
# 157  Approved   19  High school graduate - high school diploma or ...    Male
# 158  Approved   53  Professional degree (for example: MD, DDS, DVM...    Male
# 159  Approved   41  Master's degree (for example: MA, MS, MEng, ME...  Female
# 160  Approved   43        Bachelor's degree (for example: BA, AB, BS)    Male
# 161  Approved   30        Bachelor's degree (for example: BA, AB, BS)    Male
#
#                          Occupation Field Relationship/Marital Status
# 0                   Hospitality & Tourism                     Married  \
# 1                           Manufacturing                     Married
# 2    Business Management & Administration                      Single
# 3                                 Finance                      Single
# 4                                  Retail                      Single
# ..                                    ...                         ...
# 157                                 Other                      Single
# 158                                 Legal                      Single
# 159                               Finance                     Married
# 160                Information Technology           In a relationship
# 161                Information Technology                      Single
#
#        Political Party Gender Country Of Residence  Household Income
# 0             Democrat    Man        United States   $40,000-$49,999  \
# 1           Republican    Man        United States   $70,000-$79,999
# 2             Democrat  Woman        United States   $40,000-$49,999
# 3    Prefer not to say  Woman        United States   $90,000-$99,999
# 4             Democrat  Woman        United States   $50,000-$59,999
# ..                 ...    ...                  ...               ...
# 157        Independent    Man        United States  $250,000 or more
# 158        Independent    Man        United States   $20,000-$29,999
# 159         Republican  Woman        United States   $50,000-$59,999
# 160         Republican    Man        United States   $70,000-$79,999
# 161           Democrat    Man        United States   $80,000-$89,999
#
#                           Race Employment Status
# 0                        White         Full-time
# 1                        White         Full-time
# 2                        White         Full-time
# 3                        White         Full-time
# 4                        White         Full-time
# ..                         ...               ...
# 157                      White           Student
# 158                      White         Part-time
# 159  Black or African American         Full-time
# 160                    Chinese    Business Owner
# 161  Black or African American         Full-time
#
# [162 rows x 12 columns]

# %%
to_remove = data[(data.Status=='Returned')].index
data = data.drop(to_remove)

# %%
ages = data['Age'].values
ages
# Out:
# array([45, 48, 30, 27, 27, 25, 32, 34, 62, 37, 61, 58, 34, 38, 47, 56, 60,
#        39, 37, 42, 38, 32, 27, 27, 37, 27, 48, 33, 47, 56, 46, 33, 27, 46,
#        65, 21, 24, 28, 39, 31, 31, 36, 30, 46, 27, 60, 44, 21, 44, 33, 45,
#        48, 44, 48, 32, 47, 45, 35, 28, 29, 40, 28, 19, 21, 30, 60, 56, 43,
#        34, 40, 40, 30, 65, 36, 36, 26, 31, 49, 57, 27, 35, 53, 29, 31, 37,
#        38, 22, 43, 32, 40, 47, 34, 26, 27, 43, 32, 34, 26, 23, 27, 43, 35,
#        35, 26, 29, 27, 40, 26, 33, 51, 42, 27, 52, 43, 29, 27, 33, 50, 63,
#        65, 56, 30, 52, 37, 23, 36, 32, 38, 57, 24, 65, 40, 41, 47, 41, 28,
#        34, 37, 55, 26, 43, 61, 46, 35, 58, 19, 53, 41, 43, 30],
#       dtype=int64)

# %%
plt.hist(ages)
plt.show()
